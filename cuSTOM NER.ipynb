# %%
from nltk.corpus import wordnet

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets('net pay')
# Out:
# []

# %%
from nltk.corpus import wordnet

synonyms = []
word = 'pwd'
for synonym in wordnet.synsets(word):
   for item in synonym.lemmas():
      if word != synonym.name() and len(synonym.lemma_names()) > 1:
        synonyms.append(item.name())

print(synonyms)
# Out:
# []

# %%
# !python -m spacy download python -m spacy download en_core_web_md
# Out:
# [x] No compatible model found for 'python' (spaCy v2.3.7).

# %%
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity
print('Imported Successfully!')
# Out:
# Imported Successfully!

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
similar("YL2229","YL2229")
# Out:
# 1.0

# %%
def main():
    str1= "aADARSH_PANDEY"
    str2= "ANAYRA"
    print("NLP Similarity=",nlp(str1).similarity(nlp(str2)))
    print("Diff lib similarity",SequenceMatcher(None, str1, str2).ratio()) 
    print("Jellyfish lib similarity",jellyfish.jaro_distance(str1, str2))

if __name__ == '__main__':

    #python3 -m spacy download en_core_web_sm
    #nlp = spacy.load("en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")
    main()
# Out:
# NLP Similarity= 0.46573304738379984
# Diff lib similarity 0.3
# Jellyfish lib similarity 0.6507936507936508
# <ipython-input-63-ec86de4264a5>:4: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print("NLP Similarity=",nlp(str1).similarity(nlp(str2)))

# %%
import jellyfish

# %%
# !pip install |jellyfish
# Out:
# 'jellyfish' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python -m pip install jellyfish

# %%
import json
import spacy
# load the training data
with open('C:\\Users\\Lenovo\\OneDrive\\Desktop\\pvr.json') as fp:
  training_data = json.load(fp)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-67-576be9ca47d8> in <module>
#       3 # load the training data
#       4 with open('C:\\Users\\Lenovo\\OneDrive\\Desktop\\pvr.json') as fp:
# ----> 5   training_data = json.load(fp)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from tqdm import tqdm
import pandas as pd

# %%
input = pd.read_csv('C:\\Users\\Lenovo\\OneDrive\\Desktop\\pvr.csv')
row_nums = len(input.index)
print("Number of rows is: ", len(input.index))
for x in range (0,row_nums):
    print(x, " LOOP START")
    doc=nlp(input['Text'].values[x])
    print(doc.text)
    for ent in doc2.ents:
        print(ent.label_, ent.text)
# Out:
# Number of rows is:  1001
# 0  LOOP START
# MQ938548A
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-892a1b2ef011> in <module>
#       6     doc=nlp(input['Text'].values[x])
#       7     print(doc.text)
# ----> 8     for ent in doc2.ents:
#       9         print(ent.label_, ent.text)
#
# NameError: name 'doc2' is not defined

# %%
TRAIN_DATA = [('MQ938548A', {'entities': [(0, 9, 'NINO')]}),
('IG994441D', {'entities': [(0, 9, 'NINO')]}),
('GJ050822A', {'entities': [(0, 9, 'NINO')]}),
('MJ856000C', {'entities': [(0, 9, 'NINO')]}),
('FI911014D', {'entities': [(0, 9, 'NINO')]}),
('HQ257069D', {'entities': [(0, 9, 'NINO')]}),
('BS521956A', {'entities': [(0, 9, 'NINO')]}),
('ZC443091B', {'entities': [(0, 9, 'NINO')]}),
('TA990531C', {'entities': [(0, 9, 'NINO')]}),
('AR009026B', {'entities': [(0, 9, 'NINO')]}),
('EC248990A', {'entities': [(0, 9, 'NINO')]}),
('FA115007D', {'entities': [(0, 9, 'NINO')]}),
('VK154689C', {'entities': [(0, 9, 'NINO')]}),
('AF455812C', {'entities': [(0, 9, 'NINO')]}),
('ZC115316D', {'entities': [(0, 9, 'NINO')]}),
('SR605965B', {'entities': [(0, 9, 'NINO')]}),
('TP928531D', {'entities': [(0, 9, 'NINO')]}),
('ZD631808A', {'entities': [(0, 9, 'NINO')]}),
('MD384821D', {'entities': [(0, 9, 'NINO')]}),
('NX777262C', {'entities': [(0, 9, 'NINO')]}),
('DS881750B', {'entities': [(0, 9, 'NINO')]}),
('JV478977A', {'entities': [(0, 9, 'NINO')]}),
('WT102690C', {'entities': [(0, 9, 'NINO')]}),
('PO810098C', {'entities': [(0, 9, 'NINO')]}),
('PS706219C', {'entities': [(0, 9, 'NINO')]}),
('DO221235A', {'entities': [(0, 9, 'NINO')]}),
('AO733856D', {'entities': [(0, 9, 'NINO')]}),
('GL883587C', {'entities': [(0, 9, 'NINO')]}),
('KM087173B', {'entities': [(0, 9, 'NINO')]}),
('TE314217A', {'entities': [(0, 9, 'NINO')]}),
('YC680261B', {'entities': [(0, 9, 'NINO')]}),
('GG124789B', {'entities': [(0, 9, 'NINO')]}),
('WC374410C', {'entities': [(0, 9, 'NINO')]}),
('OR290660A', {'entities': [(0, 9, 'NINO')]}),
('UY016841A', {'entities': [(0, 9, 'NINO')]}),
('TW216157B', {'entities': [(0, 9, 'NINO')]}),
('KI097047C', {'entities': [(0, 9, 'NINO')]}),
('LT795414A', {'entities': [(0, 9, 'NINO')]}),
('QR009307B', {'entities': [(0, 9, 'NINO')]}),
('OH699593B', {'entities': [(0, 9, 'NINO')]}),
('QT665601D', {'entities': [(0, 9, 'NINO')]}),
('EQ654341D', {'entities': [(0, 9, 'NINO')]}),
('HY444440A', {'entities': [(0, 9, 'NINO')]}),
('NV777200B', {'entities': [(0, 9, 'NINO')]}),
('HU124137A', {'entities': [(0, 9, 'NINO')]}),
('WP041214B', {'entities': [(0, 9, 'NINO')]}),
('BX061387D', {'entities': [(0, 9, 'NINO')]}),
('WM979161B', {'entities': [(0, 9, 'NINO')]}),
('WJ003736D', {'entities': [(0, 9, 'NINO')]}),
('VZ684039B', {'entities': [(0, 9, 'NINO')]}),
('ZC456866A', {'entities': [(0, 9, 'NINO')]}),
('GA613413D', {'entities': [(0, 9, 'NINO')]}),
('FX544788D', {'entities': [(0, 9, 'NINO')]}),
('QZ340783C', {'entities': [(0, 9, 'NINO')]}),
('RV233785B', {'entities': [(0, 9, 'NINO')]}),
('JM864638D', {'entities': [(0, 9, 'NINO')]}),
('RD767057A', {'entities': [(0, 9, 'NINO')]}),
('BC869298C', {'entities': [(0, 9, 'NINO')]}),
('JR025682A', {'entities': [(0, 9, 'NINO')]}),
('WO841109D', {'entities': [(0, 9, 'NINO')]}),
('EK749891B', {'entities': [(0, 9, 'NINO')]}),
('AB425160D', {'entities': [(0, 9, 'NINO')]}),
('KX694625D', {'entities': [(0, 9, 'NINO')]}),
('TH764711B', {'entities': [(0, 9, 'NINO')]}),
('UD268227B', {'entities': [(0, 9, 'NINO')]}),
('YV135827A', {'entities': [(0, 9, 'NINO')]}),
('DH280042D', {'entities': [(0, 9, 'NINO')]}),
('ZU285394A', {'entities': [(0, 9, 'NINO')]}),
('FO432784B', {'entities': [(0, 9, 'NINO')]}),
('IJ517043C', {'entities': [(0, 9, 'NINO')]}),
('ZC069373C', {'entities': [(0, 9, 'NINO')]}),
('HA624621B', {'entities': [(0, 9, 'NINO')]}),
('MM869373B', {'entities': [(0, 9, 'NINO')]}),
('DH060779C', {'entities': [(0, 9, 'NINO')]}),
('EQ966709D', {'entities': [(0, 9, 'NINO')]}),
('QF496061D', {'entities': [(0, 9, 'NINO')]}),
('UD828542B', {'entities': [(0, 9, 'NINO')]}),
('MH121435C', {'entities': [(0, 9, 'NINO')]}),
('KM589819B', {'entities': [(0, 9, 'NINO')]}),
('VH338705D', {'entities': [(0, 9, 'NINO')]}),
('MC368628C', {'entities': [(0, 9, 'NINO')]}),
('UH521082D', {'entities': [(0, 9, 'NINO')]}),
('RY986192D', {'entities': [(0, 9, 'NINO')]}),
('AC045330C', {'entities': [(0, 9, 'NINO')]}),
('DE392498A', {'entities': [(0, 9, 'NINO')]}),
('EP871051B', {'entities': [(0, 9, 'NINO')]}),
('SZ877418A', {'entities': [(0, 9, 'NINO')]}),
('UG232119A', {'entities': [(0, 9, 'NINO')]}),
('UM226488D', {'entities': [(0, 9, 'NINO')]}),
('TJ838736A', {'entities': [(0, 9, 'NINO')]}),
('YK526278C', {'entities': [(0, 9, 'NINO')]}),
('PG236473B', {'entities': [(0, 9, 'NINO')]}),
('SP957584C', {'entities': [(0, 9, 'NINO')]}),
('EV975240B', {'entities': [(0, 9, 'NINO')]}),
('VA568787D', {'entities': [(0, 9, 'NINO')]}),
('BD034280C', {'entities': [(0, 9, 'NINO')]}),
('LI373370A', {'entities': [(0, 9, 'NINO')]}),
('BX290657B', {'entities': [(0, 9, 'NINO')]}),
('OE151665D', {'entities': [(0, 9, 'NINO')]}),
('PA792224C', {'entities': [(0, 9, 'NINO')]}),
('VU713185A', {'entities': [(0, 9, 'NINO')]}),
('FF105835B', {'entities': [(0, 9, 'NINO')]}),
('PQ248993A', {'entities': [(0, 9, 'NINO')]}),
('IA059711A', {'entities': [(0, 9, 'NINO')]}),
('TG048220A', {'entities': [(0, 9, 'NINO')]}),
('AT561869B', {'entities': [(0, 9, 'NINO')]}),
('IV478395A', {'entities': [(0, 9, 'NINO')]}),
('EO479278C', {'entities': [(0, 9, 'NINO')]}),
('SU680659A', {'entities': [(0, 9, 'NINO')]}),
('KQ666239A', {'entities': [(0, 9, 'NINO')]}),
('OP767939B', {'entities': [(0, 9, 'NINO')]}),
('IQ806202D', {'entities': [(0, 9, 'NINO')]}),
('DN218663A', {'entities': [(0, 9, 'NINO')]}),
('XT501449C', {'entities': [(0, 9, 'NINO')]}),
('DB845639B', {'entities': [(0, 9, 'NINO')]}),
('WR068392D', {'entities': [(0, 9, 'NINO')]}),
('PY719168C', {'entities': [(0, 9, 'NINO')]}),
('IL821147B', {'entities': [(0, 9, 'NINO')]}),
('AB415825C', {'entities': [(0, 9, 'NINO')]}),
('IG929016D', {'entities': [(0, 9, 'NINO')]}),
('KZ117474A', {'entities': [(0, 9, 'NINO')]}),
('RW298427C', {'entities': [(0, 9, 'NINO')]}),
('FF256881D', {'entities': [(0, 9, 'NINO')]}),
('WV520925C', {'entities': [(0, 9, 'NINO')]}),
('XI468978C', {'entities': [(0, 9, 'NINO')]}),
('KG995868C', {'entities': [(0, 9, 'NINO')]}),
('XC668923A', {'entities': [(0, 9, 'NINO')]}),
('QN621951D', {'entities': [(0, 9, 'NINO')]}),
('JU547038A', {'entities': [(0, 9, 'NINO')]}),
('ZW474684A', {'entities': [(0, 9, 'NINO')]}),
('EH664462B', {'entities': [(0, 9, 'NINO')]}),
('EA399002D', {'entities': [(0, 9, 'NINO')]}),
('UW996925D', {'entities': [(0, 9, 'NINO')]}),
('JK088311A', {'entities': [(0, 9, 'NINO')]}),
('CF624861D', {'entities': [(0, 9, 'NINO')]}),
('JV638196A', {'entities': [(0, 9, 'NINO')]}),
('HJ309892D', {'entities': [(0, 9, 'NINO')]}),
('NV058127A', {'entities': [(0, 9, 'NINO')]}),
('GK302395D', {'entities': [(0, 9, 'NINO')]}),
('PA430140D', {'entities': [(0, 9, 'NINO')]}),
('UJ930760D', {'entities': [(0, 9, 'NINO')]}),
('EC367629D', {'entities': [(0, 9, 'NINO')]}),
('MH043725D', {'entities': [(0, 9, 'NINO')]}),
('LO468131C', {'entities': [(0, 9, 'NINO')]}),
('GX860938B', {'entities': [(0, 9, 'NINO')]}),
('RI739918C', {'entities': [(0, 9, 'NINO')]}),
('PU878604C', {'entities': [(0, 9, 'NINO')]}),
('VR730950A', {'entities': [(0, 9, 'NINO')]}),
('LI522004D', {'entities': [(0, 9, 'NINO')]}),
('WH819511D', {'entities': [(0, 9, 'NINO')]}),
('FH498665B', {'entities': [(0, 9, 'NINO')]}),
('RK969952C', {'entities': [(0, 9, 'NINO')]}),
('QT058796C', {'entities': [(0, 9, 'NINO')]}),
('OK069432B', {'entities': [(0, 9, 'NINO')]}),
('CG622051A', {'entities': [(0, 9, 'NINO')]}),
('HV349827A', {'entities': [(0, 9, 'NINO')]}),
('GL441217C', {'entities': [(0, 9, 'NINO')]}),
('LU082287C', {'entities': [(0, 9, 'NINO')]}),
('PK029214D', {'entities': [(0, 9, 'NINO')]}),
('YM264919B', {'entities': [(0, 9, 'NINO')]}),
('EJ077100D', {'entities': [(0, 9, 'NINO')]}),
('WY649292C', {'entities': [(0, 9, 'NINO')]}),
('BK841701D', {'entities': [(0, 9, 'NINO')]}),
('QQ178600D', {'entities': [(0, 9, 'NINO')]}),
('UG197552D', {'entities': [(0, 9, 'NINO')]}),
('DB153579D', {'entities': [(0, 9, 'NINO')]}),
('AF157729C', {'entities': [(0, 9, 'NINO')]}),
('EH995795D', {'entities': [(0, 9, 'NINO')]}),
('VW970072B', {'entities': [(0, 9, 'NINO')]}),
('ZB887853B', {'entities': [(0, 9, 'NINO')]}),
('IK650207A', {'entities': [(0, 9, 'NINO')]}),
('ES073960C', {'entities': [(0, 9, 'NINO')]}),
('FY463659B', {'entities': [(0, 9, 'NINO')]}),
('SB219645C', {'entities': [(0, 9, 'NINO')]}),
('SQ274161D', {'entities': [(0, 9, 'NINO')]}),
('KP086867D', {'entities': [(0, 9, 'NINO')]}),
('WN290243C', {'entities': [(0, 9, 'NINO')]}),
('FM562819C', {'entities': [(0, 9, 'NINO')]}),
('WZ786326C', {'entities': [(0, 9, 'NINO')]}),
('AD769202C', {'entities': [(0, 9, 'NINO')]}),
('QD445179B', {'entities': [(0, 9, 'NINO')]}),
('MF906911B', {'entities': [(0, 9, 'NINO')]}),
('KB762429C', {'entities': [(0, 9, 'NINO')]}),
('SC673890B', {'entities': [(0, 9, 'NINO')]}),
('HX270227A', {'entities': [(0, 9, 'NINO')]}),
('RO351551C', {'entities': [(0, 9, 'NINO')]}),
('IV548115B', {'entities': [(0, 9, 'NINO')]}),
('HD201463B', {'entities': [(0, 9, 'NINO')]}),
('UC275768A', {'entities': [(0, 9, 'NINO')]}),
('GH553021D', {'entities': [(0, 9, 'NINO')]}),
('QY728016A', {'entities': [(0, 9, 'NINO')]}),
('RS281703A', {'entities': [(0, 9, 'NINO')]}),
('WK812742B', {'entities': [(0, 9, 'NINO')]}),
('EG171748A', {'entities': [(0, 9, 'NINO')]}),
('JJ180190A', {'entities': [(0, 9, 'NINO')]}),
('VA707987C', {'entities': [(0, 9, 'NINO')]}),
('US769479B', {'entities': [(0, 9, 'NINO')]}),
('OU758777D', {'entities': [(0, 9, 'NINO')]}),
('HI009150C', {'entities': [(0, 9, 'NINO')]}),
('HB538359B', {'entities': [(0, 9, 'NINO')]}),
('DP210716B', {'entities': [(0, 9, 'NINO')]}),
('RT035351C', {'entities': [(0, 9, 'NINO')]}),
('IB541823D', {'entities': [(0, 9, 'NINO')]}),
('ME908311B', {'entities': [(0, 9, 'NINO')]}),
('PL272294B', {'entities': [(0, 9, 'NINO')]}),
('AK470142D', {'entities': [(0, 9, 'NINO')]}),
('VD784300B', {'entities': [(0, 9, 'NINO')]}),
('HW692845A', {'entities': [(0, 9, 'NINO')]}),
('MG352617C', {'entities': [(0, 9, 'NINO')]}),
('FV844744D', {'entities': [(0, 9, 'NINO')]}),
('ZK119003C', {'entities': [(0, 9, 'NINO')]}),
('RY418731A', {'entities': [(0, 9, 'NINO')]}),
('XJ641280C', {'entities': [(0, 9, 'NINO')]}),
('AA533979B', {'entities': [(0, 9, 'NINO')]}),
('HH489270C', {'entities': [(0, 9, 'NINO')]}),
('EI912749D', {'entities': [(0, 9, 'NINO')]}),
('LH499004C', {'entities': [(0, 9, 'NINO')]}),
('VL026086A', {'entities': [(0, 9, 'NINO')]}),
('UJ386741C', {'entities': [(0, 9, 'NINO')]}),
('CV217621D', {'entities': [(0, 9, 'NINO')]}),
('RS275508C', {'entities': [(0, 9, 'NINO')]}),
('JZ093600B', {'entities': [(0, 9, 'NINO')]}),
('ZZ616930B', {'entities': [(0, 9, 'NINO')]}),
('FT924461C', {'entities': [(0, 9, 'NINO')]}),
('NE377567C', {'entities': [(0, 9, 'NINO')]}),
('MU377770C', {'entities': [(0, 9, 'NINO')]}),
('XW282453B', {'entities': [(0, 9, 'NINO')]}),
('ZD397148D', {'entities': [(0, 9, 'NINO')]}),
('EV190978A', {'entities': [(0, 9, 'NINO')]}),
('VW401819A', {'entities': [(0, 9, 'NINO')]}),
('YL309784D', {'entities': [(0, 9, 'NINO')]}),
('US590130B', {'entities': [(0, 9, 'NINO')]}),
('DX895117D', {'entities': [(0, 9, 'NINO')]}),
('OP306397A', {'entities': [(0, 9, 'NINO')]}),
('HQ742443A', {'entities': [(0, 9, 'NINO')]}),
('ET104843A', {'entities': [(0, 9, 'NINO')]}),
('SH379203A', {'entities': [(0, 9, 'NINO')]}),
('EK910769D', {'entities': [(0, 9, 'NINO')]}),
('PV861589D', {'entities': [(0, 9, 'NINO')]}),
('QP172463B', {'entities': [(0, 9, 'NINO')]}),
('PJ867955A', {'entities': [(0, 9, 'NINO')]}),
('BG418707C', {'entities': [(0, 9, 'NINO')]}),
('QM041868B', {'entities': [(0, 9, 'NINO')]}),
('IG077113B', {'entities': [(0, 9, 'NINO')]}),
('GA508484D', {'entities': [(0, 9, 'NINO')]}),
('RX499930D', {'entities': [(0, 9, 'NINO')]}),
('RM171149D', {'entities': [(0, 9, 'NINO')]}),
('MC660869D', {'entities': [(0, 9, 'NINO')]}),
('HI405188B', {'entities': [(0, 9, 'NINO')]}),
('UK531631A', {'entities': [(0, 9, 'NINO')]}),
('OW268276A', {'entities': [(0, 9, 'NINO')]}),
('NZ081079A', {'entities': [(0, 9, 'NINO')]}),
('PJ179604A', {'entities': [(0, 9, 'NINO')]}),
('DB833017D', {'entities': [(0, 9, 'NINO')]}),
('MH389133C', {'entities': [(0, 9, 'NINO')]}),
('DN524361B', {'entities': [(0, 9, 'NINO')]}),
('JP705124B', {'entities': [(0, 9, 'NINO')]}),
('SF464132A', {'entities': [(0, 9, 'NINO')]}),
('EO281830A', {'entities': [(0, 9, 'NINO')]}),
('GE686990C', {'entities': [(0, 9, 'NINO')]}),
('MK712056C', {'entities': [(0, 9, 'NINO')]}),
('UA333739C', {'entities': [(0, 9, 'NINO')]}),
('UH425178D', {'entities': [(0, 9, 'NINO')]}),
('IE106585D', {'entities': [(0, 9, 'NINO')]}),
('RN210639D', {'entities': [(0, 9, 'NINO')]}),
('NU897921B', {'entities': [(0, 9, 'NINO')]}),
('JE999516D', {'entities': [(0, 9, 'NINO')]}),
('PO222017D', {'entities': [(0, 9, 'NINO')]}),
('YU912986B', {'entities': [(0, 9, 'NINO')]}),
('HD700612A', {'entities': [(0, 9, 'NINO')]}),
('UB876600A', {'entities': [(0, 9, 'NINO')]}),
('PL208726D', {'entities': [(0, 9, 'NINO')]}),
('YI544445B', {'entities': [(0, 9, 'NINO')]}),
('MT312933A', {'entities': [(0, 9, 'NINO')]}),
('IX931798D', {'entities': [(0, 9, 'NINO')]}),
('ZG797830D', {'entities': [(0, 9, 'NINO')]}),
('HE086488A', {'entities': [(0, 9, 'NINO')]}),
('PU958530B', {'entities': [(0, 9, 'NINO')]}),
('JD183370C', {'entities': [(0, 9, 'NINO')]}),
('XM549437B', {'entities': [(0, 9, 'NINO')]}),
('DB503595D', {'entities': [(0, 9, 'NINO')]}),
('II642371C', {'entities': [(0, 9, 'NINO')]}),
('TE917481B', {'entities': [(0, 9, 'NINO')]}),
('FA995169D', {'entities': [(0, 9, 'NINO')]}),
('SE875663A', {'entities': [(0, 9, 'NINO')]}),
('LP039390B', {'entities': [(0, 9, 'NINO')]}),
('VL515536A', {'entities': [(0, 9, 'NINO')]}),
('AX157080B', {'entities': [(0, 9, 'NINO')]}),
('ZD401002C', {'entities': [(0, 9, 'NINO')]}),
('AM574778B', {'entities': [(0, 9, 'NINO')]}),
('TQ726384D', {'entities': [(0, 9, 'NINO')]}),
('ST316115B', {'entities': [(0, 9, 'NINO')]}),
('ZP358972A', {'entities': [(0, 9, 'NINO')]}),
('QR245189D', {'entities': [(0, 9, 'NINO')]}),
('FT333395B', {'entities': [(0, 9, 'NINO')]}),
('HX573058D', {'entities': [(0, 9, 'NINO')]}),
('UH415906B', {'entities': [(0, 9, 'NINO')]}),
('CI214152D', {'entities': [(0, 9, 'NINO')]}),
('GQ020673D', {'entities': [(0, 9, 'NINO')]}),
('FQ713286A', {'entities': [(0, 9, 'NINO')]}),
('FU708901B', {'entities': [(0, 9, 'NINO')]}),
('XQ548116B', {'entities': [(0, 9, 'NINO')]}),
('TY928136C', {'entities': [(0, 9, 'NINO')]}),
('XO244051D', {'entities': [(0, 9, 'NINO')]}),
('WP968508D', {'entities': [(0, 9, 'NINO')]}),
('RF855904C', {'entities': [(0, 9, 'NINO')]}),
('FH955789A', {'entities': [(0, 9, 'NINO')]}),
('DM780087B', {'entities': [(0, 9, 'NINO')]}),
('WT076484C', {'entities': [(0, 9, 'NINO')]}),
('KV985385D', {'entities': [(0, 9, 'NINO')]}),
('GV666920C', {'entities': [(0, 9, 'NINO')]}),
('ET219229A', {'entities': [(0, 9, 'NINO')]}),
('AD634552A', {'entities': [(0, 9, 'NINO')]}),
('LQ280652B', {'entities': [(0, 9, 'NINO')]}),
('JN355192D', {'entities': [(0, 9, 'NINO')]}),
('PY843013B', {'entities': [(0, 9, 'NINO')]}),
('AY325826C', {'entities': [(0, 9, 'NINO')]}),
('PX926967A', {'entities': [(0, 9, 'NINO')]}),
('GZ651428C', {'entities': [(0, 9, 'NINO')]}),
('BS575246C', {'entities': [(0, 9, 'NINO')]}),
('AE718341D', {'entities': [(0, 9, 'NINO')]}),
('JM260670A', {'entities': [(0, 9, 'NINO')]}),
('OD381894B', {'entities': [(0, 9, 'NINO')]}),
('ZN060110C', {'entities': [(0, 9, 'NINO')]}),
('EA183842B', {'entities': [(0, 9, 'NINO')]}),
('QQ206384D', {'entities': [(0, 9, 'NINO')]}),
('OX080517C', {'entities': [(0, 9, 'NINO')]}),
('ZD905051A', {'entities': [(0, 9, 'NINO')]}),
('NU611754C', {'entities': [(0, 9, 'NINO')]}),
('PR606791B', {'entities': [(0, 9, 'NINO')]}),
('DA275452C', {'entities': [(0, 9, 'NINO')]}),
('SX983500D', {'entities': [(0, 9, 'NINO')]}),
('CI448029A', {'entities': [(0, 9, 'NINO')]}),
('ZD544756D', {'entities': [(0, 9, 'NINO')]}),
('YE275810C', {'entities': [(0, 9, 'NINO')]}),
('MZ657870D', {'entities': [(0, 9, 'NINO')]}),
('TP368555C', {'entities': [(0, 9, 'NINO')]}),
('QD719983A', {'entities': [(0, 9, 'NINO')]}),
('XU740404A', {'entities': [(0, 9, 'NINO')]}),
('EU659177D', {'entities': [(0, 9, 'NINO')]}),
('OS772750C', {'entities': [(0, 9, 'NINO')]}),
('BB887183A', {'entities': [(0, 9, 'NINO')]}),
('WX214568B', {'entities': [(0, 9, 'NINO')]}),
('LR358113A', {'entities': [(0, 9, 'NINO')]}),
('CH177772A', {'entities': [(0, 9, 'NINO')]}),
('BI783668A', {'entities': [(0, 9, 'NINO')]}),
('WH320668C', {'entities': [(0, 9, 'NINO')]}),
('VN169746C', {'entities': [(0, 9, 'NINO')]}),
('SF024063A', {'entities': [(0, 9, 'NINO')]}),
('EB380494D', {'entities': [(0, 9, 'NINO')]}),
('EQ069901D', {'entities': [(0, 9, 'NINO')]}),
('XQ194117B', {'entities': [(0, 9, 'NINO')]}),
('BA715383D', {'entities': [(0, 9, 'NINO')]}),
('CW517041D', {'entities': [(0, 9, 'NINO')]}),
('WJ300442B', {'entities': [(0, 9, 'NINO')]}),
('OI594325B', {'entities': [(0, 9, 'NINO')]}),
('SA061234B', {'entities': [(0, 9, 'NINO')]}),
('KN864925D', {'entities': [(0, 9, 'NINO')]}),
('TI475108C', {'entities': [(0, 9, 'NINO')]}),
('NB631307D', {'entities': [(0, 9, 'NINO')]}),
('PH966617C', {'entities': [(0, 9, 'NINO')]}),
('FM281012B', {'entities': [(0, 9, 'NINO')]}),
('KY586533C', {'entities': [(0, 9, 'NINO')]}),
('GF925331B', {'entities': [(0, 9, 'NINO')]}),
('MR439451A', {'entities': [(0, 9, 'NINO')]}),
('CC516696D', {'entities': [(0, 9, 'NINO')]}),
('LA169413A', {'entities': [(0, 9, 'NINO')]}),
('DJ417100D', {'entities': [(0, 9, 'NINO')]}),
('HK032895B', {'entities': [(0, 9, 'NINO')]}),
('SL908374D', {'entities': [(0, 9, 'NINO')]}),
('AJ721844A', {'entities': [(0, 9, 'NINO')]}),
('MF509911A', {'entities': [(0, 9, 'NINO')]}),
('IN991532D', {'entities': [(0, 9, 'NINO')]}),
('TI335212A', {'entities': [(0, 9, 'NINO')]}),
('BN383772B', {'entities': [(0, 9, 'NINO')]}),
('VP431100B', {'entities': [(0, 9, 'NINO')]}),
('WZ927935C', {'entities': [(0, 9, 'NINO')]}),
('CM881178A', {'entities': [(0, 9, 'NINO')]}),
('UT287946D', {'entities': [(0, 9, 'NINO')]}),
('ST494670C', {'entities': [(0, 9, 'NINO')]}),
('OB050591C', {'entities': [(0, 9, 'NINO')]}),
('DJ020699D', {'entities': [(0, 9, 'NINO')]}),
('VK476333D', {'entities': [(0, 9, 'NINO')]}),
('NK706773C', {'entities': [(0, 9, 'NINO')]}),
('QY400495C', {'entities': [(0, 9, 'NINO')]}),
('DU514240A', {'entities': [(0, 9, 'NINO')]}),
('WO952737D', {'entities': [(0, 9, 'NINO')]}),
('JZ543971C', {'entities': [(0, 9, 'NINO')]}),
('UE153711C', {'entities': [(0, 9, 'NINO')]}),
('NO698082C', {'entities': [(0, 9, 'NINO')]}),
('XE918299B', {'entities': [(0, 9, 'NINO')]}),
('OB544751A', {'entities': [(0, 9, 'NINO')]}),
('YX903737D', {'entities': [(0, 9, 'NINO')]}),
('YV369968A', {'entities': [(0, 9, 'NINO')]}),
('YK792156D', {'entities': [(0, 9, 'NINO')]}),
('AQ269423D', {'entities': [(0, 9, 'NINO')]}),
('ZT039355C', {'entities': [(0, 9, 'NINO')]}),
('KA059869D', {'entities': [(0, 9, 'NINO')]}),
('EZ004659D', {'entities': [(0, 9, 'NINO')]}),
('AW749411C', {'entities': [(0, 9, 'NINO')]}),
('LG758757B', {'entities': [(0, 9, 'NINO')]}),
('HF964913D', {'entities': [(0, 9, 'NINO')]}),
('VX429584A', {'entities': [(0, 9, 'NINO')]}),
('ZH629079A', {'entities': [(0, 9, 'NINO')]}),
('LP302911C', {'entities': [(0, 9, 'NINO')]}),
('AJ871179A', {'entities': [(0, 9, 'NINO')]}),
('MK459689A', {'entities': [(0, 9, 'NINO')]}),
('VF835601C', {'entities': [(0, 9, 'NINO')]}),
('EU430108D', {'entities': [(0, 9, 'NINO')]}),
('EV076895C', {'entities': [(0, 9, 'NINO')]}),
('XS562636D', {'entities': [(0, 9, 'NINO')]}),
('GX390971D', {'entities': [(0, 9, 'NINO')]}),
('YW661046B', {'entities': [(0, 9, 'NINO')]}),
('MN855489C', {'entities': [(0, 9, 'NINO')]}),
('KK220531C', {'entities': [(0, 9, 'NINO')]}),
('IV475092A', {'entities': [(0, 9, 'NINO')]}),
('BC517186C', {'entities': [(0, 9, 'NINO')]}),
('NL683684A', {'entities': [(0, 9, 'NINO')]}),
('EK939976C', {'entities': [(0, 9, 'NINO')]}),
('BB994274A', {'entities': [(0, 9, 'NINO')]}),
('WI810491C', {'entities': [(0, 9, 'NINO')]}),
('SP639252B', {'entities': [(0, 9, 'NINO')]}),
('WI980590C', {'entities': [(0, 9, 'NINO')]}),
('FU471719C', {'entities': [(0, 9, 'NINO')]}),
('ID786583B', {'entities': [(0, 9, 'NINO')]}),
('NX124001A', {'entities': [(0, 9, 'NINO')]}),
('FE576106A', {'entities': [(0, 9, 'NINO')]}),
('OF971752D', {'entities': [(0, 9, 'NINO')]}),
('LS995014D', {'entities': [(0, 9, 'NINO')]}),
('TJ016048B', {'entities': [(0, 9, 'NINO')]}),
('DK225703B', {'entities': [(0, 9, 'NINO')]}),
('KP398104A', {'entities': [(0, 9, 'NINO')]}),
('YB154037C', {'entities': [(0, 9, 'NINO')]}),
('VK880837C', {'entities': [(0, 9, 'NINO')]}),
('EM668500A', {'entities': [(0, 9, 'NINO')]}),
('WP112793B', {'entities': [(0, 9, 'NINO')]}),
('EG000191C', {'entities': [(0, 9, 'NINO')]}),
('MS670030D', {'entities': [(0, 9, 'NINO')]}),
('CR155502A', {'entities': [(0, 9, 'NINO')]}),
('NG097319C', {'entities': [(0, 9, 'NINO')]}),
('JV614486C', {'entities': [(0, 9, 'NINO')]}),
('UX673221D', {'entities': [(0, 9, 'NINO')]}),
('OJ507117C', {'entities': [(0, 9, 'NINO')]}),
('CR732915B', {'entities': [(0, 9, 'NINO')]}),
('OF714922D', {'entities': [(0, 9, 'NINO')]}),
('FT817693B', {'entities': [(0, 9, 'NINO')]}),
('RI923524D', {'entities': [(0, 9, 'NINO')]}),
('MK945968C', {'entities': [(0, 9, 'NINO')]}),
('US759517B', {'entities': [(0, 9, 'NINO')]}),
('EZ175467A', {'entities': [(0, 9, 'NINO')]}),
('FL399144B', {'entities': [(0, 9, 'NINO')]}),
('PU525472D', {'entities': [(0, 9, 'NINO')]}),
('LD362026B', {'entities': [(0, 9, 'NINO')]}),
('CR117857D', {'entities': [(0, 9, 'NINO')]}),
('YF679942A', {'entities': [(0, 9, 'NINO')]}),
('XP545421D', {'entities': [(0, 9, 'NINO')]}),
('HR052651B', {'entities': [(0, 9, 'NINO')]}),
('AN401111B', {'entities': [(0, 9, 'NINO')]}),
('EO855832D', {'entities': [(0, 9, 'NINO')]}),
('IH470321C', {'entities': [(0, 9, 'NINO')]}),
('RM097417D', {'entities': [(0, 9, 'NINO')]}),
('SG202754B', {'entities': [(0, 9, 'NINO')]}),
('YI660085C', {'entities': [(0, 9, 'NINO')]}),
('EB722643D', {'entities': [(0, 9, 'NINO')]}),
('AS974143C', {'entities': [(0, 9, 'NINO')]}),
('CG253718A', {'entities': [(0, 9, 'NINO')]}),
('MQ155888C', {'entities': [(0, 9, 'NINO')]}),
('LZ389881D', {'entities': [(0, 9, 'NINO')]}),
('KA441891C', {'entities': [(0, 9, 'NINO')]}),
('DR259846A', {'entities': [(0, 9, 'NINO')]}),
('WL150416B', {'entities': [(0, 9, 'NINO')]}),
('PY025556D', {'entities': [(0, 9, 'NINO')]}),
('NF792517C', {'entities': [(0, 9, 'NINO')]}),
('UQ961741D', {'entities': [(0, 9, 'NINO')]}),
('JC189496B', {'entities': [(0, 9, 'NINO')]}),
('MD134075D', {'entities': [(0, 9, 'NINO')]}),
('ZH027280B', {'entities': [(0, 9, 'NINO')]}),
('UX125828A', {'entities': [(0, 9, 'NINO')]}),
('ZO957304A', {'entities': [(0, 9, 'NINO')]}),
('QH480665D', {'entities': [(0, 9, 'NINO')]}),
('UV017983D', {'entities': [(0, 9, 'NINO')]}),
('TC557748D', {'entities': [(0, 9, 'NINO')]}),
('FJ377840A', {'entities': [(0, 9, 'NINO')]}),
('UR310706C', {'entities': [(0, 9, 'NINO')]}),
('FA256371B', {'entities': [(0, 9, 'NINO')]}),
('JJ899702B', {'entities': [(0, 9, 'NINO')]}),
('XZ092371A', {'entities': [(0, 9, 'NINO')]}),
('HU662876D', {'entities': [(0, 9, 'NINO')]}),
('ZP058056B', {'entities': [(0, 9, 'NINO')]}),
('SR210812A', {'entities': [(0, 9, 'NINO')]}),
('OP926016D', {'entities': [(0, 9, 'NINO')]}),
('BB280792C', {'entities': [(0, 9, 'NINO')]}),
('FP810751A', {'entities': [(0, 9, 'NINO')]}),
('JQ210765C', {'entities': [(0, 9, 'NINO')]}),
('TB436764A', {'entities': [(0, 9, 'NINO')]}),
('IT779968D', {'entities': [(0, 9, 'NINO')]}),
('MK730716A', {'entities': [(0, 9, 'NINO')]}),
('GH899228B', {'entities': [(0, 9, 'NINO')]}),
('HF878784C', {'entities': [(0, 9, 'NINO')]}),
('AQ076158A', {'entities': [(0, 9, 'NINO')]}),
('EN230174C', {'entities': [(0, 9, 'NINO')]}),
('JW811871D', {'entities': [(0, 9, 'NINO')]}),
('XT947246A', {'entities': [(0, 9, 'NINO')]}),
('NU609829A', {'entities': [(0, 9, 'NINO')]}),
('CZ553755B', {'entities': [(0, 9, 'NINO')]}),
('SH701703B', {'entities': [(0, 9, 'NINO')]}),
('SD916935A', {'entities': [(0, 9, 'NINO')]}),
('BV681969A', {'entities': [(0, 9, 'NINO')]}),
('MK421006A', {'entities': [(0, 9, 'NINO')]}),
('ZZ523082A', {'entities': [(0, 9, 'NINO')]}),
('ZN917183B', {'entities': [(0, 9, 'NINO')]}),
('QD195137B', {'entities': [(0, 9, 'NINO')]}),
('VV484782B', {'entities': [(0, 9, 'NINO')]}),
('EZ940217B', {'entities': [(0, 9, 'NINO')]}),
('VZ035546C', {'entities': [(0, 9, 'NINO')]}),
('DQ206890C', {'entities': [(0, 9, 'NINO')]}),
('TP202112C', {'entities': [(0, 9, 'NINO')]}),
('TI898409C', {'entities': [(0, 9, 'NINO')]}),
('IQ011118B', {'entities': [(0, 9, 'NINO')]}),
('HE945013A', {'entities': [(0, 9, 'NINO')]}),
('GT785013A', {'entities': [(0, 9, 'NINO')]}),
('CR112628A', {'entities': [(0, 9, 'NINO')]}),
('YU287661B', {'entities': [(0, 9, 'NINO')]}),
('DG837932B', {'entities': [(0, 9, 'NINO')]}),
('MA431347B', {'entities': [(0, 9, 'NINO')]}),
('UN489424A', {'entities': [(0, 9, 'NINO')]}),
('HE821957D', {'entities': [(0, 9, 'NINO')]}),
('BY570734B', {'entities': [(0, 9, 'NINO')]}),
('KU728134A', {'entities': [(0, 9, 'NINO')]}),
('EB382414C', {'entities': [(0, 9, 'NINO')]}),
('PW037439C', {'entities': [(0, 9, 'NINO')]}),
('OL881793D', {'entities': [(0, 9, 'NINO')]}),
('XV045040C', {'entities': [(0, 9, 'NINO')]}),
('EA920500B', {'entities': [(0, 9, 'NINO')]}),
('AR762270A', {'entities': [(0, 9, 'NINO')]}),
('VX084278D', {'entities': [(0, 9, 'NINO')]}),
('NB550257A', {'entities': [(0, 9, 'NINO')]}),
('JL003733C', {'entities': [(0, 9, 'NINO')]}),
('KL639715A', {'entities': [(0, 9, 'NINO')]}),
('FE104085B', {'entities': [(0, 9, 'NINO')]}),
('QZ695523C', {'entities': [(0, 9, 'NINO')]}),
('GT572330B', {'entities': [(0, 9, 'NINO')]}),
('LN764751D', {'entities': [(0, 9, 'NINO')]}),
('DK028935A', {'entities': [(0, 9, 'NINO')]}),
('FR469183D', {'entities': [(0, 9, 'NINO')]}),
('BX123031A', {'entities': [(0, 9, 'NINO')]}),
('WO767751C', {'entities': [(0, 9, 'NINO')]}),
('ML391192C', {'entities': [(0, 9, 'NINO')]}),
('VV936922C', {'entities': [(0, 9, 'NINO')]}),
('YQ877500A', {'entities': [(0, 9, 'NINO')]}),
('GT794414A', {'entities': [(0, 9, 'NINO')]}),
('IR808205B', {'entities': [(0, 9, 'NINO')]}),
('LE098585D', {'entities': [(0, 9, 'NINO')]}),
('YA220512B', {'entities': [(0, 9, 'NINO')]}),
('GL762976A', {'entities': [(0, 9, 'NINO')]}),
('ZO396405B', {'entities': [(0, 9, 'NINO')]}),
('DA438901C', {'entities': [(0, 9, 'NINO')]}),
('FQ518847D', {'entities': [(0, 9, 'NINO')]}),
('VM800865B', {'entities': [(0, 9, 'NINO')]}),
('LQ884444A', {'entities': [(0, 9, 'NINO')]}),
('VU808873B', {'entities': [(0, 9, 'NINO')]}),
('QO073223C', {'entities': [(0, 9, 'NINO')]}),
('IP368273A', {'entities': [(0, 9, 'NINO')]}),
('UE198879A', {'entities': [(0, 9, 'NINO')]}),
('OJ759010D', {'entities': [(0, 9, 'NINO')]}),
('BS151124D', {'entities': [(0, 9, 'NINO')]}),
('KT192659C', {'entities': [(0, 9, 'NINO')]}),
('BH638541D', {'entities': [(0, 9, 'NINO')]}),
('ET595996A', {'entities': [(0, 9, 'NINO')]}),
('AF562357C', {'entities': [(0, 9, 'NINO')]}),
('HZ508172D', {'entities': [(0, 9, 'NINO')]}),
('QT950617D', {'entities': [(0, 9, 'NINO')]}),
('NC067344C', {'entities': [(0, 9, 'NINO')]}),
('KG231849D', {'entities': [(0, 9, 'NINO')]}),
('LP545099B', {'entities': [(0, 9, 'NINO')]}),
('ED608045B', {'entities': [(0, 9, 'NINO')]}),
('MV104908C', {'entities': [(0, 9, 'NINO')]}),
('LJ526211D', {'entities': [(0, 9, 'NINO')]}),
('UR342037B', {'entities': [(0, 9, 'NINO')]}),
('PX416440C', {'entities': [(0, 9, 'NINO')]}),
('ME719481B', {'entities': [(0, 9, 'NINO')]}),
('OT079103A', {'entities': [(0, 9, 'NINO')]}),
('SV073582C', {'entities': [(0, 9, 'NINO')]}),
('HF471113D', {'entities': [(0, 9, 'NINO')]}),
('ZA532920D', {'entities': [(0, 9, 'NINO')]}),
('OI724752C', {'entities': [(0, 9, 'NINO')]}),
('IK210350D', {'entities': [(0, 9, 'NINO')]}),
('KA246515A', {'entities': [(0, 9, 'NINO')]}),
('KM621305C', {'entities': [(0, 9, 'NINO')]}),
('PI925104C', {'entities': [(0, 9, 'NINO')]}),
('NR325142C', {'entities': [(0, 9, 'NINO')]}),
('TW297309B', {'entities': [(0, 9, 'NINO')]}),
('ZQ774879B', {'entities': [(0, 9, 'NINO')]}),
('TG746005A', {'entities': [(0, 9, 'NINO')]}),
('DJ467429B', {'entities': [(0, 9, 'NINO')]}),
('DE030188D', {'entities': [(0, 9, 'NINO')]}),
('LM116926B', {'entities': [(0, 9, 'NINO')]}),
('OE084913C', {'entities': [(0, 9, 'NINO')]}),
('XV183258A', {'entities': [(0, 9, 'NINO')]}),
('JV094652D', {'entities': [(0, 9, 'NINO')]}),
('FV771713A', {'entities': [(0, 9, 'NINO')]}),
('PH103111A', {'entities': [(0, 9, 'NINO')]}),
('ZQ048716D', {'entities': [(0, 9, 'NINO')]}),
('ZD350306B', {'entities': [(0, 9, 'NINO')]}),
('AV060668C', {'entities': [(0, 9, 'NINO')]}),
('YA265943B', {'entities': [(0, 9, 'NINO')]}),
('MS088001A', {'entities': [(0, 9, 'NINO')]}),
('VB621849C', {'entities': [(0, 9, 'NINO')]}),
('VW502028C', {'entities': [(0, 9, 'NINO')]}),
('KW550400A', {'entities': [(0, 9, 'NINO')]}),
('YC601070C', {'entities': [(0, 9, 'NINO')]}),
('LI508814A', {'entities': [(0, 9, 'NINO')]}),
('XL563498A', {'entities': [(0, 9, 'NINO')]}),
('GH104461D', {'entities': [(0, 9, 'NINO')]}),
('WX558749C', {'entities': [(0, 9, 'NINO')]}),
('DX180451C', {'entities': [(0, 9, 'NINO')]}),
('HD135613D', {'entities': [(0, 9, 'NINO')]}),
('NE622911C', {'entities': [(0, 9, 'NINO')]}),
('GJ639085C', {'entities': [(0, 9, 'NINO')]}),
('CF352866C', {'entities': [(0, 9, 'NINO')]}),
('NZ939718A', {'entities': [(0, 9, 'NINO')]}),
('QI440458D', {'entities': [(0, 9, 'NINO')]}),
('XU844447A', {'entities': [(0, 9, 'NINO')]}),
('FI001543D', {'entities': [(0, 9, 'NINO')]}),
('OX293834A', {'entities': [(0, 9, 'NINO')]}),
('VN006627A', {'entities': [(0, 9, 'NINO')]}),
('NZ907981D', {'entities': [(0, 9, 'NINO')]}),
('MV580793D', {'entities': [(0, 9, 'NINO')]}),
('UZ334605C', {'entities': [(0, 9, 'NINO')]}),
('GQ018910D', {'entities': [(0, 9, 'NINO')]}),
('XG324304C', {'entities': [(0, 9, 'NINO')]}),
('OR100982D', {'entities': [(0, 9, 'NINO')]}),
('KR739587D', {'entities': [(0, 9, 'NINO')]}),
('AF474284C', {'entities': [(0, 9, 'NINO')]}),
('CC853530D', {'entities': [(0, 9, 'NINO')]}),
('UN296520B', {'entities': [(0, 9, 'NINO')]}),
('SO685778C', {'entities': [(0, 9, 'NINO')]}),
('XT909668A', {'entities': [(0, 9, 'NINO')]}),
('BO018312D', {'entities': [(0, 9, 'NINO')]}),
('VD892838C', {'entities': [(0, 9, 'NINO')]}),
('LB679166B', {'entities': [(0, 9, 'NINO')]}),
('HP675142A', {'entities': [(0, 9, 'NINO')]}),
('JC000103D', {'entities': [(0, 9, 'NINO')]}),
('VP550463D', {'entities': [(0, 9, 'NINO')]}),
('ZH343156B', {'entities': [(0, 9, 'NINO')]}),
('VV742799D', {'entities': [(0, 9, 'NINO')]}),
('AH960079C', {'entities': [(0, 9, 'NINO')]}),
('QV125950D', {'entities': [(0, 9, 'NINO')]}),
('UU385767D', {'entities': [(0, 9, 'NINO')]}),
('EF615874B', {'entities': [(0, 9, 'NINO')]}),
('RJ775146C', {'entities': [(0, 9, 'NINO')]}),
('UT776936A', {'entities': [(0, 9, 'NINO')]}),
('VM313181A', {'entities': [(0, 9, 'NINO')]}),
('UT806164D', {'entities': [(0, 9, 'NINO')]}),
('YO218773D', {'entities': [(0, 9, 'NINO')]}),
('LM024281A', {'entities': [(0, 9, 'NINO')]}),
('RA645986A', {'entities': [(0, 9, 'NINO')]}),
('QJ292055C', {'entities': [(0, 9, 'NINO')]}),
('FQ499880D', {'entities': [(0, 9, 'NINO')]}),
('ZO391825B', {'entities': [(0, 9, 'NINO')]}),
('GO965419A', {'entities': [(0, 9, 'NINO')]}),
('NM783968D', {'entities': [(0, 9, 'NINO')]}),
('VY330044D', {'entities': [(0, 9, 'NINO')]}),
('QB616528A', {'entities': [(0, 9, 'NINO')]}),
('CY953847D', {'entities': [(0, 9, 'NINO')]}),
('MX797114A', {'entities': [(0, 9, 'NINO')]}),
('HA675355D', {'entities': [(0, 9, 'NINO')]}),
('WN498586D', {'entities': [(0, 9, 'NINO')]}),
('JJ547701A', {'entities': [(0, 9, 'NINO')]}),
('NL350840C', {'entities': [(0, 9, 'NINO')]}),
('LC321989B', {'entities': [(0, 9, 'NINO')]}),
('ME846818B', {'entities': [(0, 9, 'NINO')]}),
('QO491430A', {'entities': [(0, 9, 'NINO')]}),
('YO076726D', {'entities': [(0, 9, 'NINO')]}),
('US290752B', {'entities': [(0, 9, 'NINO')]}),
('LS236807A', {'entities': [(0, 9, 'NINO')]}),
('ZJ118976D', {'entities': [(0, 9, 'NINO')]}),
('TU636485B', {'entities': [(0, 9, 'NINO')]}),
('KL615290B', {'entities': [(0, 9, 'NINO')]}),
('CS008045C', {'entities': [(0, 9, 'NINO')]}),
('WR184132A', {'entities': [(0, 9, 'NINO')]}),
('QN332013D', {'entities': [(0, 9, 'NINO')]}),
('JD360943C', {'entities': [(0, 9, 'NINO')]}),
('NV637484B', {'entities': [(0, 9, 'NINO')]}),
('VB088109C', {'entities': [(0, 9, 'NINO')]}),
('CX264147B', {'entities': [(0, 9, 'NINO')]}),
('IZ715039C', {'entities': [(0, 9, 'NINO')]}),
('FF626183A', {'entities': [(0, 9, 'NINO')]}),
('HY670773B', {'entities': [(0, 9, 'NINO')]}),
('RY116947C', {'entities': [(0, 9, 'NINO')]}),
('YO252637B', {'entities': [(0, 9, 'NINO')]}),
('ZV084874C', {'entities': [(0, 9, 'NINO')]}),
('UY693343C', {'entities': [(0, 9, 'NINO')]}),
('YT593456B', {'entities': [(0, 9, 'NINO')]}),
('LZ616086B', {'entities': [(0, 9, 'NINO')]}),
('HU230071C', {'entities': [(0, 9, 'NINO')]}),
('VT419427A', {'entities': [(0, 9, 'NINO')]}),
('PZ425631D', {'entities': [(0, 9, 'NINO')]}),
('PK042901B', {'entities': [(0, 9, 'NINO')]}),
('EF850002C', {'entities': [(0, 9, 'NINO')]}),
('NG832526C', {'entities': [(0, 9, 'NINO')]}),
('EI777149C', {'entities': [(0, 9, 'NINO')]}),
('EH368352A', {'entities': [(0, 9, 'NINO')]}),
('II952156B', {'entities': [(0, 9, 'NINO')]}),
('BI480801C', {'entities': [(0, 9, 'NINO')]}),
('EU010294C', {'entities': [(0, 9, 'NINO')]}),
('WS836810A', {'entities': [(0, 9, 'NINO')]}),
('ZQ151850A', {'entities': [(0, 9, 'NINO')]}),
('VG609713D', {'entities': [(0, 9, 'NINO')]}),
('EA021900B', {'entities': [(0, 9, 'NINO')]}),
('NN445952A', {'entities': [(0, 9, 'NINO')]}),
('VX000107C', {'entities': [(0, 9, 'NINO')]}),
('BE167709C', {'entities': [(0, 9, 'NINO')]}),
('KJ645567A', {'entities': [(0, 9, 'NINO')]}),
('TN179241A', {'entities': [(0, 9, 'NINO')]}),
('OV664717B', {'entities': [(0, 9, 'NINO')]}),
('OC426750C', {'entities': [(0, 9, 'NINO')]}),
('BK483829A', {'entities': [(0, 9, 'NINO')]}),
('BS781849A', {'entities': [(0, 9, 'NINO')]}),
('FG549876A', {'entities': [(0, 9, 'NINO')]}),
('LL065219D', {'entities': [(0, 9, 'NINO')]}),
('LP197403A', {'entities': [(0, 9, 'NINO')]}),
('ZL120521B', {'entities': [(0, 9, 'NINO')]}),
('MY436179D', {'entities': [(0, 9, 'NINO')]}),
('OM559762A', {'entities': [(0, 9, 'NINO')]}),
('UA534704A', {'entities': [(0, 9, 'NINO')]}),
('WH450912A', {'entities': [(0, 9, 'NINO')]}),
('UM613059B', {'entities': [(0, 9, 'NINO')]}),
('UO305637C', {'entities': [(0, 9, 'NINO')]}),
('FE499371C', {'entities': [(0, 9, 'NINO')]}),
('JD871717C', {'entities': [(0, 9, 'NINO')]}),
('XE882674B', {'entities': [(0, 9, 'NINO')]}),
('KL722116D', {'entities': [(0, 9, 'NINO')]}),
('GK865557C', {'entities': [(0, 9, 'NINO')]}),
('ZN432207B', {'entities': [(0, 9, 'NINO')]}),
('QW750070B', {'entities': [(0, 9, 'NINO')]}),
('HU643860A', {'entities': [(0, 9, 'NINO')]}),
('JW738981C', {'entities': [(0, 9, 'NINO')]}),
('NO419866B', {'entities': [(0, 9, 'NINO')]}),
('KT880370C', {'entities': [(0, 9, 'NINO')]}),
('BG098131D', {'entities': [(0, 9, 'NINO')]}),
('WN456164D', {'entities': [(0, 9, 'NINO')]}),
('KU132631D', {'entities': [(0, 9, 'NINO')]}),
('WJ860023B', {'entities': [(0, 9, 'NINO')]}),
('FC839926B', {'entities': [(0, 9, 'NINO')]}),
('FD415424D', {'entities': [(0, 9, 'NINO')]}),
('HA152450D', {'entities': [(0, 9, 'NINO')]}),
('FN494560D', {'entities': [(0, 9, 'NINO')]}),
('FM600206B', {'entities': [(0, 9, 'NINO')]}),
('RZ812826C', {'entities': [(0, 9, 'NINO')]}),
('MC417243B', {'entities': [(0, 9, 'NINO')]}),
('HK602211B', {'entities': [(0, 9, 'NINO')]}),
('OS588565C', {'entities': [(0, 9, 'NINO')]}),
('RG382265B', {'entities': [(0, 9, 'NINO')]}),
('LI854241C', {'entities': [(0, 9, 'NINO')]}),
('ET046517B', {'entities': [(0, 9, 'NINO')]}),
('UV324262A', {'entities': [(0, 9, 'NINO')]}),
('RF823131D', {'entities': [(0, 9, 'NINO')]}),
('OH263324B', {'entities': [(0, 9, 'NINO')]}),
('FN028152D', {'entities': [(0, 9, 'NINO')]}),
('KM324104A', {'entities': [(0, 9, 'NINO')]}),
('WC360860C', {'entities': [(0, 9, 'NINO')]}),
('AU416640D', {'entities': [(0, 9, 'NINO')]}),
('TJ966710A', {'entities': [(0, 9, 'NINO')]}),
('HA328757B', {'entities': [(0, 9, 'NINO')]}),
('NB303922C', {'entities': [(0, 9, 'NINO')]}),
('BR263462D', {'entities': [(0, 9, 'NINO')]}),
('GN247130B', {'entities': [(0, 9, 'NINO')]}),
('VL264494B', {'entities': [(0, 9, 'NINO')]}),
('LU054594D', {'entities': [(0, 9, 'NINO')]}),
('WG882999B', {'entities': [(0, 9, 'NINO')]}),
('IS377454B', {'entities': [(0, 9, 'NINO')]}),
('MJ465732C', {'entities': [(0, 9, 'NINO')]}),
('IW081205B', {'entities': [(0, 9, 'NINO')]}),
('VX800231B', {'entities': [(0, 9, 'NINO')]}),
('WR311472B', {'entities': [(0, 9, 'NINO')]}),
('GX170752D', {'entities': [(0, 9, 'NINO')]}),
('GA148281C', {'entities': [(0, 9, 'NINO')]}),
('FU557939D', {'entities': [(0, 9, 'NINO')]}),
('UW963846C', {'entities': [(0, 9, 'NINO')]}),
('HD851310D', {'entities': [(0, 9, 'NINO')]}),
('DU896213C', {'entities': [(0, 9, 'NINO')]}),
('LD568441D', {'entities': [(0, 9, 'NINO')]}),
('TY982555C', {'entities': [(0, 9, 'NINO')]}),
('RH275137D', {'entities': [(0, 9, 'NINO')]}),
('NR594734A', {'entities': [(0, 9, 'NINO')]}),
('OS381213C', {'entities': [(0, 9, 'NINO')]}),
('IN229332D', {'entities': [(0, 9, 'NINO')]}),
('TZ633107C', {'entities': [(0, 9, 'NINO')]}),
('XJ622728C', {'entities': [(0, 9, 'NINO')]}),
('CP192397D', {'entities': [(0, 9, 'NINO')]}),
('FU208641A', {'entities': [(0, 9, 'NINO')]}),
('RR047865A', {'entities': [(0, 9, 'NINO')]}),
('PZ030802C', {'entities': [(0, 9, 'NINO')]}),
('FA405637D', {'entities': [(0, 9, 'NINO')]}),
('DP478076A', {'entities': [(0, 9, 'NINO')]}),
('FI010356A', {'entities': [(0, 9, 'NINO')]}),
('GU313538B', {'entities': [(0, 9, 'NINO')]}),
('TY027500D', {'entities': [(0, 9, 'NINO')]}),
('GK514991A', {'entities': [(0, 9, 'NINO')]}),
('PN140821C', {'entities': [(0, 9, 'NINO')]}),
('MB979739D', {'entities': [(0, 9, 'NINO')]}),
('PX466534B', {'entities': [(0, 9, 'NINO')]}),
('GK940409B', {'entities': [(0, 9, 'NINO')]}),
('ZP032535C', {'entities': [(0, 9, 'NINO')]}),
('BG562408B', {'entities': [(0, 9, 'NINO')]}),
('MA311048A', {'entities': [(0, 9, 'NINO')]}),
('VX264935B', {'entities': [(0, 9, 'NINO')]}),
('VX188164C', {'entities': [(0, 9, 'NINO')]}),
('QH231716A', {'entities': [(0, 9, 'NINO')]}),
('JD238563D', {'entities': [(0, 9, 'NINO')]}),
('KQ652539C', {'entities': [(0, 9, 'NINO')]}),
('HT590397D', {'entities': [(0, 9, 'NINO')]}),
('QO774050B', {'entities': [(0, 9, 'NINO')]}),
('DF445097A', {'entities': [(0, 9, 'NINO')]}),
('YQ285571D', {'entities': [(0, 9, 'NINO')]}),
('OW178771A', {'entities': [(0, 9, 'NINO')]}),
('EB025712D', {'entities': [(0, 9, 'NINO')]}),
('LC441402C', {'entities': [(0, 9, 'NINO')]}),
('EO593782D', {'entities': [(0, 9, 'NINO')]}),
('WK642804C', {'entities': [(0, 9, 'NINO')]}),
('CA360533D', {'entities': [(0, 9, 'NINO')]}),
('MM901354C', {'entities': [(0, 9, 'NINO')]}),
('NE230171A', {'entities': [(0, 9, 'NINO')]}),
('XF347250A', {'entities': [(0, 9, 'NINO')]}),
('TM013192A', {'entities': [(0, 9, 'NINO')]}),
('LE567717A', {'entities': [(0, 9, 'NINO')]}),
('IB149440D', {'entities': [(0, 9, 'NINO')]}),
('JQ832104C', {'entities': [(0, 9, 'NINO')]}),
('QD194133B', {'entities': [(0, 9, 'NINO')]}),
('SD902607A', {'entities': [(0, 9, 'NINO')]}),
('RQ647587C', {'entities': [(0, 9, 'NINO')]}),
('PZ495067B', {'entities': [(0, 9, 'NINO')]}),
('ER791694C', {'entities': [(0, 9, 'NINO')]}),
('QJ303385D', {'entities': [(0, 9, 'NINO')]}),
('SG687858C', {'entities': [(0, 9, 'NINO')]}),
('LT065834C', {'entities': [(0, 9, 'NINO')]}),
('QH102122B', {'entities': [(0, 9, 'NINO')]}),
('VG982305B', {'entities': [(0, 9, 'NINO')]}),
('AD518422B', {'entities': [(0, 9, 'NINO')]}),
('UU681561D', {'entities': [(0, 9, 'NINO')]}),
('IW074103C', {'entities': [(0, 9, 'NINO')]}),
('AA014313B', {'entities': [(0, 9, 'NINO')]}),
('IQ135427B', {'entities': [(0, 9, 'NINO')]}),
('SF310383B', {'entities': [(0, 9, 'NINO')]}),
('XZ847727D', {'entities': [(0, 9, 'NINO')]}),
('MR746577B', {'entities': [(0, 9, 'NINO')]}),
('NF662514A', {'entities': [(0, 9, 'NINO')]}),
('XJ795951A', {'entities': [(0, 9, 'NINO')]}),
('EL830350D', {'entities': [(0, 9, 'NINO')]}),
('BJ519859C', {'entities': [(0, 9, 'NINO')]}),
('CN578616C', {'entities': [(0, 9, 'NINO')]}),
('CD690772D', {'entities': [(0, 9, 'NINO')]}),
('UE995372A', {'entities': [(0, 9, 'NINO')]}),
('NA998926A', {'entities': [(0, 9, 'NINO')]}),
('NG930530D', {'entities': [(0, 9, 'NINO')]}),
('LT757915A', {'entities': [(0, 9, 'NINO')]}),
('PF171458C', {'entities': [(0, 9, 'NINO')]}),
('OT461196B', {'entities': [(0, 9, 'NINO')]}),
('GW194091A', {'entities': [(0, 9, 'NINO')]}),
('PO247304A', {'entities': [(0, 9, 'NINO')]}),
('SX360790B', {'entities': [(0, 9, 'NINO')]}),
('GR672609B', {'entities': [(0, 9, 'NINO')]}),
('XV295779D', {'entities': [(0, 9, 'NINO')]}),
('IX935571D', {'entities': [(0, 9, 'NINO')]}),
('KI462092B', {'entities': [(0, 9, 'NINO')]}),
('AM904270D', {'entities': [(0, 9, 'NINO')]}),
('RV982089B', {'entities': [(0, 9, 'NINO')]}),
('IY885671C', {'entities': [(0, 9, 'NINO')]}),
('UE817931D', {'entities': [(0, 9, 'NINO')]}),
('EC745292B', {'entities': [(0, 9, 'NINO')]}),
('JN863484A', {'entities': [(0, 9, 'NINO')]}),
('DF138377D', {'entities': [(0, 9, 'NINO')]}),
('QY406280C', {'entities': [(0, 9, 'NINO')]}),
('MJ985022D', {'entities': [(0, 9, 'NINO')]}),
('UV752042C', {'entities': [(0, 9, 'NINO')]}),
('PH366006C', {'entities': [(0, 9, 'NINO')]}),
('IU843820B', {'entities': [(0, 9, 'NINO')]}),
('HV971499A', {'entities': [(0, 9, 'NINO')]}),
('GY250103D', {'entities': [(0, 9, 'NINO')]}),
('AU694891A', {'entities': [(0, 9, 'NINO')]}),
('NN025532C', {'entities': [(0, 9, 'NINO')]}),
('WR627521D', {'entities': [(0, 9, 'NINO')]}),
('BW711916B', {'entities': [(0, 9, 'NINO')]}),
('IC502980A', {'entities': [(0, 9, 'NINO')]}),
('WG289796C', {'entities': [(0, 9, 'NINO')]}),
('GG017491C', {'entities': [(0, 9, 'NINO')]}),
('VA048026C', {'entities': [(0, 9, 'NINO')]}),
('DF044372C', {'entities': [(0, 9, 'NINO')]}),
('DB787688A', {'entities': [(0, 9, 'NINO')]}),
('UF074349C', {'entities': [(0, 9, 'NINO')]}),
('LJ153545D', {'entities': [(0, 9, 'NINO')]}),
('HT725957A', {'entities': [(0, 9, 'NINO')]}),
('ZS438901A', {'entities': [(0, 9, 'NINO')]}),
('LW720356D', {'entities': [(0, 9, 'NINO')]}),
('DW466922D', {'entities': [(0, 9, 'NINO')]}),
('RD533856C', {'entities': [(0, 9, 'NINO')]}),
('CS510433A', {'entities': [(0, 9, 'NINO')]}),
('MG135046B', {'entities': [(0, 9, 'NINO')]}),
('QH369445D', {'entities': [(0, 9, 'NINO')]}),
('RE696741A', {'entities': [(0, 9, 'NINO')]}),
('QS881887B', {'entities': [(0, 9, 'NINO')]}),
('RY188922B', {'entities': [(0, 9, 'NINO')]}),
('TY342697C', {'entities': [(0, 9, 'NINO')]}),
('EN335206B', {'entities': [(0, 9, 'NINO')]}),
('UJ779004A', {'entities': [(0, 9, 'NINO')]}),
('SC975400A', {'entities': [(0, 9, 'NINO')]}),
('BF824984B', {'entities': [(0, 9, 'NINO')]}),
('YC410473C', {'entities': [(0, 9, 'NINO')]}),
('BR401068C', {'entities': [(0, 9, 'NINO')]}),
('GC645490D', {'entities': [(0, 9, 'NINO')]}),
('FG117052C', {'entities': [(0, 9, 'NINO')]}),
('AI334577B', {'entities': [(0, 9, 'NINO')]}),
('MY729321B', {'entities': [(0, 9, 'NINO')]}),
('DN527116A', {'entities': [(0, 9, 'NINO')]}),
('LD694703B', {'entities': [(0, 9, 'NINO')]}),
('PC126255C', {'entities': [(0, 9, 'NINO')]}),
('DL308032D', {'entities': [(0, 9, 'NINO')]}),
('HE510804D', {'entities': [(0, 9, 'NINO')]}),
('AF890373B', {'entities': [(0, 9, 'NINO')]}),
('IT605085D', {'entities': [(0, 9, 'NINO')]}),
('LO260459B', {'entities': [(0, 9, 'NINO')]}),
('JY724835C', {'entities': [(0, 9, 'NINO')]}),
('TJ095904B', {'entities': [(0, 9, 'NINO')]}),
('OU308805D', {'entities': [(0, 9, 'NINO')]}),
('OG048691C', {'entities': [(0, 9, 'NINO')]}),
('LD554885C', {'entities': [(0, 9, 'NINO')]}),
('XK509789A', {'entities': [(0, 9, 'NINO')]}),
('IZ935039A', {'entities': [(0, 9, 'NINO')]}),
('MV465010D', {'entities': [(0, 9, 'NINO')]}),
('AC142569C', {'entities': [(0, 9, 'NINO')]}),
('PK643104B', {'entities': [(0, 9, 'NINO')]}),
('OU078843B', {'entities': [(0, 9, 'NINO')]}),
('SP635549D', {'entities': [(0, 9, 'NINO')]}),
('GT691949A', {'entities': [(0, 9, 'NINO')]}),
('HD012526B', {'entities': [(0, 9, 'NINO')]}),
('LB666900D', {'entities': [(0, 9, 'NINO')]}),
('EF331303A', {'entities': [(0, 9, 'NINO')]}),
('YD045396B', {'entities': [(0, 9, 'NINO')]}),
('LB947380B', {'entities': [(0, 9, 'NINO')]}),
('RJ523623A', {'entities': [(0, 9, 'NINO')]}),
('HA270968B', {'entities': [(0, 9, 'NINO')]}),
('MD556612C', {'entities': [(0, 9, 'NINO')]}),
('QF446031A', {'entities': [(0, 9, 'NINO')]}),
('XJ215617D', {'entities': [(0, 9, 'NINO')]}),
('CN978490C', {'entities': [(0, 9, 'NINO')]}),
('LR013103C', {'entities': [(0, 9, 'NINO')]}),
('JI689325C', {'entities': [(0, 9, 'NINO')]}),
('QG911920B', {'entities': [(0, 9, 'NINO')]}),
('YA546024B', {'entities': [(0, 9, 'NINO')]}),
('UR791351C', {'entities': [(0, 9, 'NINO')]}),
('JF536012C', {'entities': [(0, 9, 'NINO')]}),
('TO449836C', {'entities': [(0, 9, 'NINO')]}),
('YV745248C', {'entities': [(0, 9, 'NINO')]}),
('EZ052176D', {'entities': [(0, 9, 'NINO')]}),
('ZS214664D', {'entities': [(0, 9, 'NINO')]}),
('DY046498B', {'entities': [(0, 9, 'NINO')]}),
('IM449244A', {'entities': [(0, 9, 'NINO')]}),
('WH343665D', {'entities': [(0, 9, 'NINO')]}),
('ET000067D', {'entities': [(0, 9, 'NINO')]}),
('GG882862C', {'entities': [(0, 9, 'NINO')]}),
('IA492401C', {'entities': [(0, 9, 'NINO')]}),
('QI032015A', {'entities': [(0, 9, 'NINO')]}),
('AQ446283A', {'entities': [(0, 9, 'NINO')]}),
('DI186195D', {'entities': [(0, 9, 'NINO')]}),
('LO043194D', {'entities': [(0, 9, 'NINO')]}),
('CE622778B', {'entities': [(0, 9, 'NINO')]}),
('WH815702B', {'entities': [(0, 9, 'NINO')]}),
('GM771341D', {'entities': [(0, 9, 'NINO')]}),
('OP052300A', {'entities': [(0, 9, 'NINO')]}),
('WI608051A', {'entities': [(0, 9, 'NINO')]}),
('WS478514C', {'entities': [(0, 9, 'NINO')]}),
('QS337188A', {'entities': [(0, 9, 'NINO')]}),
('WN282052D', {'entities': [(0, 9, 'NINO')]}),
('CH703909A', {'entities': [(0, 9, 'NINO')]}),
('TM040964D', {'entities': [(0, 9, 'NINO')]}),
('GZ381591B', {'entities': [(0, 9, 'NINO')]}),
('FX191532C', {'entities': [(0, 9, 'NINO')]}),
('AX598290C', {'entities': [(0, 9, 'NINO')]}),
('PS655357D', {'entities': [(0, 9, 'NINO')]}),
('GC157584D', {'entities': [(0, 9, 'NINO')]}),
('VX089053C', {'entities': [(0, 9, 'NINO')]}),
('YH009213A', {'entities': [(0, 9, 'NINO')]}),
('NW053431B', {'entities': [(0, 9, 'NINO')]}),
('HU993330A', {'entities': [(0, 9, 'NINO')]}),
('HW532175A', {'entities': [(0, 9, 'NINO')]}),
('OY964189A', {'entities': [(0, 9, 'NINO')]}),
('BT318238D', {'entities': [(0, 9, 'NINO')]}),
('QH263661B', {'entities': [(0, 9, 'NINO')]}),
('GR830504C', {'entities': [(0, 9, 'NINO')]}),
('ZP485850D', {'entities': [(0, 9, 'NINO')]}),
('LE339261C', {'entities': [(0, 9, 'NINO')]}),
('LE904637A', {'entities': [(0, 9, 'NINO')]}),
('CK318285B', {'entities': [(0, 9, 'NINO')]}),
('VL301020D', {'entities': [(0, 9, 'NINO')]}),
('MW804757C', {'entities': [(0, 9, 'NINO')]}),
('KH129083D', {'entities': [(0, 9, 'NINO')]}),
('FJ455406C', {'entities': [(0, 9, 'NINO')]}),
('VY772044B', {'entities': [(0, 9, 'NINO')]}),
('UX105422A', {'entities': [(0, 9, 'NINO')]}),
('OG121560D', {'entities': [(0, 9, 'NINO')]})]

# %%
model = None
output_dir=Path("C:\\Users\\Lenovo\\OneDrive\\Documents\\ner")
n_iter=1

# %%
if model is not None:
    nlp = spacy.load(model)  
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank('en')  
    print("Created blank 'en' model")

#set up the pipeline

if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
else:
    ner = nlp.get_pipe('ner')
# Out:
# Created blank 'en' model

# %%
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in tqdm(TRAIN_DATA):
            nlp.update(
                [text],  
                [annotations],  
                drop=0.5,  
                sgd=optimizer,
                losses=losses)
        print(losses)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1001/1001 [00:50<00:00, 19.81it/s]
# {'ner': 8.632871337145932}

# %%
print(TRAIN_DATA)
for text, _ in TRAIN_DATA:
    print(text)
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('TH764711B', {'entities': [(0, 9, 'NINO')]}), ('GM771341D', {'entities': [(0, 9, 'NINO')]}), ('PJ867955A', {'entities': [(0, 9, 'NINO')]}), ('GR830504C', {'entities': [(0, 9, 'NINO')]}), ('VW502028C', {'entities': [(0, 9, 'NINO')]}), ('AM904270D', {'entities': [(0, 9, 'NINO')]}), ('ZC069373C', {'entities': [(0, 9, 'NINO')]}), ('TG048220A', {'entities': [(0, 9, 'NINO')]}), ('SF310383B', {'entities': [(0, 9, 'NINO')]}), ('KU728134A', {'entities': [(0, 9, 'NINO')]}), ('ZO391825B', {'entities': [(0, 9, 'NINO')]}), ('SB219645C', {'entities': [(0, 9, 'NINO')]}), ('AS974143C', {'entities': [(0, 9, 'NINO')]}), ('QS881887B', {'entities': [(0, 9, 'NINO')]}), ('YU287661B', {'entities': [(0, 9, 'NINO')]}), ('XV295779D', {'entities': [(0, 9, 'NINO')]}), ('NZ939718A', {'entities': [(0, 9, 'NINO')]}), ('RS275508C', {'entities': [(0, 9, 'NINO')]}), ('RV233785B', {'entities': [(0, 9, 'NINO')]}), ('GQ020673D', {'entities': [(0, 9, 'NINO')]}), ('VL026086A', {'entities': [(0, 9, 'NINO')]}), ('BD034280
# ...

# %%
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)
# Out:
# Saved model to C:\Users\Lenovo\OneDrive\Documents\ner

# %%
print("Loading from", output_dir)
nlp2 = spacy.load(output_dir)
Train_Data
for text, _ in TRAIN_DATA:
    doc = nlp2(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Loading from C:\Users\Lenovo\OneDrive\Documents\ner
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-2f0c7bb7a4e2> in <module>
#       1 print("Loading from", output_dir)
#       2 nlp2 = spacy.load(output_dir)
# ----> 3 Train_Data
#       4 for text, _ in TRAIN_DATA:
#       5     doc = nlp2(text)
#
# NameError: name 'Train_Data' is not defined

# %%
doc = nlp2("AB830586D")

# %%
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('AB830586D', 'NINO')]
# Tokens [('AB830586D', 'NINO', 3)]
